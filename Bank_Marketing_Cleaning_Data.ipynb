# %% [markdown]
# #**Bank Marketing Dataset**
# ####By: Jessica, Carmen, Yanting and Emma
# #### Anonymous bank located in Portugal
# #### The business objective is to identify which customer characteristics are associated with a higher likelihood of subscribing to a term deposit so that marketing efforts can be focused on the most promising prospects.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-b772af35-9982-488a-8d31-662b964d10b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b772af35-9982-488a-8d31-662b964d10b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read CSV
df = pd.read_csv("bank-direct-marketing-campaigns.csv")
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ### Feature descriptions
#
# ##### Age, the category of job (admin, blue-collar, student, etc), marital status, education level, default (if they have unpaid debt), housing loan, loan (personal), contact (communication type), month (last contact month), day of week (last contact day of week), campaign (number of contacts performed), pdays (number of days after client last contacted), previous (number of contacts before this campaign), poutcome (outcome of previous campaign), emp.var.rate (emplayment variation rate), cons.price.idx (consumer price index), cons.conf.idx (consumer confidence index), euribor3m (euribor 3 month rate), nr.employed (number of employees), y (has client subscribed a term deposit?)

# %%
#shape
df.shape
# Out:
# (41188, 20)

# %%
# data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  campaign        41188 non-null  int64
#  11  pdays           41188 non-null  int64
#  12  previous        41188 non-null  int64
#  13  poutcome        41188 non-null  object
#  14  emp.var.rate    41188 non-null  float64
#  15  cons.price.idx  41188 non-null  float64
#  16  cons.conf.idx   41188 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# Drop rows where y is missing
df = df.dropna(subset=['y'])

# %%
# Count the number of data that says unknown
unknown_counts = (df == "unknown").sum()

print(unknown_counts[unknown_counts > 0])
# Out:
# job           330
# marital        80
# education    1731
# default      8597
# housing       990
# loan          990
# dtype: int64

# %%
# Percentage of data that is unknown
unknown_percent = ((df == "unknown").mean() * 100).round(2)

print(unknown_percent[unknown_percent > 0])
# Out:
# job           0.80
# marital       0.19
# education     4.20
# default      20.87
# housing       2.40
# loan          2.40
# dtype: float64

# %%
# Describe the dataset
df.describe()
# Out:
#                age      campaign         pdays      previous  emp.var.rate  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406      2.567593    962.475454      0.172963      0.081886
# std       10.42125      2.770014    186.910907      0.494901      1.570960
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41188.000000   41188.000000  41188.000000  41188.000000
# mean        93.575664     -40.502600      3.621291   5167.035911
# std          0.578840       4.628198      1.734447     72.251528
# ...

# %% [markdown]
# These are all of the features that were numerical prior to changing them to
# binary or scaling them. By describing the data it gave us a better
# understanding of how it lies before we get into cleaning it.

# %%
# Professional descriptive summary
descriptive_summary = df.describe().T
descriptive_summary
# Out:
#                   count         mean         std       min       25%  \
# age             41188.0    40.024060   10.421250    17.000    32.000
# campaign        41188.0     2.567593    2.770014     1.000     1.000
# pdays           41188.0   962.475454  186.910907     0.000   999.000
# previous        41188.0     0.172963    0.494901     0.000     0.000
# emp.var.rate    41188.0     0.081886    1.570960    -3.400    -1.800
# cons.price.idx  41188.0    93.575664    0.578840    92.201    93.075
# cons.conf.idx   41188.0   -40.502600    4.628198   -50.800   -42.700
# euribor3m       41188.0     3.621291    1.734447     0.634     1.344
# nr.employed     41188.0  5167.035911   72.251528  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# campaign           2.000     3.000    56.000
# pdays            999.000   999.000   999.000
# previous           0.000     0.000     7.000
# emp.var.rate       1.100     1.400     1.400
# ...

# %%
# Check for duplicate rows
print("Number of duplicated rows:", df.duplicated().sum())
# Out:
# Number of duplicated rows: 1784

# %%
# Delete duplicate rows
df = df.drop_duplicates()
print("New dataset shape:")
print(df.shape)
# Out:
# New dataset shape:
# (39404, 20)

# %% [markdown]
# Checked for duplicate rows and found that there were 1784 of them. So,
# we decided to drop them.

# %%
#Checking
cols_to_check = ['age', 'campaign']

# Keep a record of your original row count
original_rows = len(df)

for col in cols_to_check:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    # Calculate the IQR range
    IQR = Q3 - Q1

    # Define your upper and lower boundaries
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter the dataframe to only keep rows within the boundaries
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

print(f"Dropped {original_rows - len(df)} statistical outlier rows.")
# Out:
# Dropped 2842 statistical outlier rows.

# %%
# check for outliers
df = check_outliers(df, ['age'], 5)

# %%
df[df.outlier_age]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y, outlier_age]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = df.drop('outlier_age', axis=1)

# %% [markdown]
# There were outliars in both the age and campaign section of out data so we dropped those to prevent it from becoming skewed

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
# Change catrgorical to binary
df = pd.get_dummies(
    data=df,
    columns=['job', 'education','marital','default','housing','loan','contact','month','day_of_week','y','poutcome'],
    drop_first=True
)

# %%
df.head()
# Out:
#    age  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56         1    999         0           1.1          93.994
# 1   57         1    999         0           1.1          93.994
# 2   37         1    999         0           1.1          93.994
# 3   40         1    999         0           1.1          93.994
# 4   56         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  job_blue-collar  ...  month_nov  \
# 0          -36.4      4.857       5191.0            False  ...      False
# 1          -36.4      4.857       5191.0            False  ...      False
# 2          -36.4      4.857       5191.0            False  ...      False
# 3          -36.4      4.857       5191.0            False  ...      False
# 4          -36.4      4.857       5191.0            False  ...      False
#
#    month_oct  month_sep  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %%
bool_cols = df.select_dtypes(include='bool').columns

df[bool_cols] = df[bool_cols].astype(int)

# %%
df.head()
# Out:
#    age  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56         1    999         0           1.1          93.994
# 1   57         1    999         0           1.1          93.994
# 2   37         1    999         0           1.1          93.994
# 3   40         1    999         0           1.1          93.994
# 4   56         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  job_blue-collar  ...  month_nov  \
# 0          -36.4      4.857       5191.0                0  ...          0
# 1          -36.4      4.857       5191.0                0  ...          0
# 2          -36.4      4.857       5191.0                0  ...          0
# 3          -36.4      4.857       5191.0                0  ...          0
# 4          -36.4      4.857       5191.0                0  ...          0
#
#    month_oct  month_sep  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %% [markdown]
# By converting our categorical values into binary we are able to easily inpterpat and compare finding in duture analysis

# %%
# Scale appropriate columns
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))

cols_to_scale = [

    'campaign','previous','emp.var.rate','cons.price.idx','nr.employed','pdays','cons.conf.idx', 'euribor3m','age']

existing_cols = [c for c in cols_to_scale if c in df.columns]

df[existing_cols] = scaler.fit_transform(df[existing_cols])

df.head()
# Out:
#         age  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0  0.500000      -1.0    1.0      -1.0         0.875        0.397506
# 1  0.538462      -1.0    1.0      -1.0         0.875        0.397506
# 2 -0.230769      -1.0    1.0      -1.0         0.875        0.397506
# 3 -0.115385      -1.0    1.0      -1.0         0.875        0.397506
# 4  0.500000      -1.0    1.0      -1.0         0.875        0.397506
#
#    cons.conf.idx  euribor3m  nr.employed  job_blue-collar  ...  month_nov  \
# 0       0.205021   0.914759     0.719471                0  ...          0
# 1       0.205021   0.914759     0.719471                0  ...          0
# 2       0.205021   0.914759     0.719471                0  ...          0
# 3       0.205021   0.914759     0.719471                0  ...          0
# 4       0.205021   0.914759     0.719471                0  ...          0
#
#    month_oct  month_sep  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %% [markdown]
# We scaled the remaining numerical values for easy compairsion and so that no values would be weighted more than others withing the compairions.

# %%
# download as CSV.
output_file_path = 'bank_marketing_cleaned_for_classification.csv'
df.to_csv(output_file_path, index=False)
